# %% [markdown]
# # Import de la base `lung_dataset.csv`

# %%
#import lung_dataset.csv
import pandas as pd
lung_dataset = pd.read_csv("lung_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 #import lung_dataset.csv
# ----> 2 import pandas as pd
#       3 lung_dataset = pd.read_csv("lung_dataset.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3
